# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Data" data-toc-modified-id="Data-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Data</a></span><ul class="toc-item"><li><span><a href="#Target" data-toc-modified-id="Target-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Target</a></span></li><li><span><a href="#Type" data-toc-modified-id="Type-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Type</a></span></li><li><span><a href="#Correlation" data-toc-modified-id="Correlation-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Correlation</a></span></li><li><span><a href="#Description" data-toc-modified-id="Description-1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>Description</a></span></li><li><span><a href="#Missing-value" data-toc-modified-id="Missing-value-1.5"><span class="toc-item-num">1.5&nbsp;&nbsp;</span>Missing value</a></span></li></ul></li><li><span><a href="#Model" data-toc-modified-id="Model-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Model</a></span><ul class="toc-item"><li><span><a href="#Config" data-toc-modified-id="Config-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Config</a></span></li></ul></li><li><span><a href="#test" data-toc-modified-id="test-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>test</a></span></li></ul></div>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import missingno as no

# %% [markdown]
# # Data

# %%
data = pd.read_csv('../dataset/train.csv',index_col=0)
test = pd.read_csv('../dataset/test.csv', index_col=0)
print('dataset shape: ', data.shape)
print('testset shape: ', test.shape)
# Out:
# dataset shape:  (200000, 201)
# testset shape:  (200000, 200)

# %% [markdown]
# ## Target

# %%
data.target.value_counts()
# Out:
# 0    179902
# 1     20098
# Name: target, dtype: int64

# %%
target_values = data.target.value_counts()
print('Positive rate: {0:.3%}'.format(target_values[1]/np.sum(target_values)))
# Out:
# Positive rate: 10.049%

# %% [markdown]
# ## Type

# %%
type_list = list()
for i in range(1,data.shape[1]):
    type_list.append(data.iloc[:,i].dtype)
np.unique(type_list)
# Out:
# array([dtype('float64')], dtype=object)

# %% [markdown]
# ## Correlation

# %%
data_corr = data.iloc[:,1:].corr()
sns.heatmap(data_corr)

# %% [markdown]
# ## Description

# %%
data.describe()
# Out:
#               target          var_0          var_1          var_2  \
# count  200000.000000  200000.000000  200000.000000  200000.000000
# mean        0.100490      10.679914      -1.627622      10.715192
# std         0.300653       3.040051       4.050044       2.640894
# min         0.000000       0.408400     -15.043400       2.117100
# 25%         0.000000       8.453850      -4.740025       8.722475
# 50%         0.000000      10.524750      -1.608050      10.580000
# 75%         0.000000      12.758200       1.358625      12.516700
# max         1.000000      20.315000      10.376800      19.353000
#
#                var_3          var_4          var_5          var_6  \
# count  200000.000000  200000.000000  200000.000000  200000.000000
# mean        6.796529      11.078333      -5.065317       5.408949
# std         2.043319       1.623150       7.863267       0.866607
# min        -0.040200       5.074800     -32.562600       2.347300
# ...

# %% [markdown]
# ## Missing value

# %%
missing_features = list()
for i in range(1,data.shape[1]):
    if np.sum(data.iloc[:,i].isnull()) != 0:
        missing_features.append(data.columns[i])

# %%
missing_features
# Out:
# []

# %%
missing_features = list()
for i in range(1,test.shape[1]):
    if np.sum(test.iloc[:,i].isnull()) != 0:
        missing_features.append(test.columns[i])

# %%
missing_features
# Out:
# []

# %% [markdown]
# # Model

# %% [markdown]
# ## Config

# %%
seed = 2019
k_folds = 10

# %%
from sklearn.model_selection import StratifiedKFold
from sklearn.linear_model import LogisticRegression
from sklearn import metrics
from sklearn import preprocessing
from tqdm import tqdm

# %%
folds = StratifiedKFold(n_splits=k_folds, random_state=seed, shuffle=True)

# %%
x_data, y_data = data.iloc[:,1:], data[['target']]

# %%
cols = x_data.columns
idx = x_data.index
scaler = preprocessing.StandardScaler()
scaler.fit(x_data)
x_data = scaler.transform(x_data)
x_data = pd.DataFrame(x_data, columns=cols, index=idx)

idx = test.index
scaler = preprocessing.StandardScaler()
scaler.fit(test)
test = scaler.transform(test)
test = pd.DataFrame(test, columns=cols, index=idx)

# %%
auc_list = list()
proba = np.zeros(len(test))
for train_idx, test_idx in tqdm(folds.split(X=x_data, y=y_data)):
    x_train, y_train = x_data.iloc[train_idx,:], y_data.iloc[train_idx,:]
    x_test, y_test = x_data.iloc[test_idx,:], y_data.iloc[test_idx,:]
    model = LogisticRegression(n_jobs=8, max_iter=1000, random_state=seed, verbose=1)
    model.fit(x_train, y_train)
    pred = model.predict_proba(x_test)[:,1]
        
    auc = metrics.roc_auc_score(y_true=y_test, y_score=pred)
    auc_list.append(auc)
    
    proba += model.predict_proba(test)[:,1] / folds.n_splits
# Out:
# 0it [00:00, ?it/s]C:\Users\wogur\Anaconda3\lib\site-packages\sklearn\utils\validation.py:578: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\wogur\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:1228: UserWarning: 'n_jobs' > 1 does not have any effect when 'solver' is set to 'liblinear'. Got 'n_jobs' = 8.
#   " = {}.".format(self.n_jobs))
# [LibLinear]
# 1it [00:02,  3.00s/it]C:\Users\wogur\Anaconda3\lib\site-packages\sklearn\utils\validation.py:578: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# ...

# %%
auc_list
# Out:
# [0.8584667679334415,
#  0.8623694655509071,
#  0.8689675579855033,
#  0.8498758016476816,
#  0.8663466713126973,
#  0.8669949308488132,
#  0.8511987035362378,
#  0.8557415534888093,
#  0.8590907066062641,
#  0.8563107483804813]

# %%
np.mean(auc_list)
# Out:
# 0.8595362907290836

# %% [markdown]
# # test

# %%
plt.hist(proba)
# Out:
# (array([145405.,  26977.,  11511.,   6164.,   3763.,   2462.,   1562.,
#           1110.,    751.,    295.]),
#  array([2.89066643e-05, 9.96318528e-02, 1.99234799e-01, 2.98837745e-01,
#         3.98440691e-01, 4.98043637e-01, 5.97646583e-01, 6.97249529e-01,
#         7.96852475e-01, 8.96455422e-01, 9.96058368e-01]),
#  <a list of 10 Patch objects>)

# %%
pd.DataFrame({'ID_code':idx, 'target':proba}).to_csv('../submission/s2.csv',index=False)

# %%
test.index
# Out:
# RangeIndex(start=0, stop=200000, step=1)

# %%
import xgboost as xgb

# %%
xgb.DMatrix(test)
